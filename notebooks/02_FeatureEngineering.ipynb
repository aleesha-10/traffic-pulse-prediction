# %%
import pandas as pd

traffic = pd.read_csv(
    "../data/processed/traffic_aggregated.csv",
    parse_dates=["timestamp"],
    index_col="timestamp"
)

traffic.head()
# Out:
#                      traffic_flow
# timestamp
# 2017-01-01 00:00:00     65.831430
# 2017-01-01 00:05:00     65.468198
# 2017-01-01 00:10:00     65.468198
# 2017-01-01 00:15:00     65.468198
# 2017-01-01 00:20:00     65.468198

# %% [markdown]
# Time-based features (calendar intelligence)

# %%
df = traffic.copy()

df["hour"] = df.index.hour
df["day_of_week"] = df.index.dayofweek
df["is_weekend"] = (df["day_of_week"] >= 5).astype(int)

# %% [markdown]
# Lag features (core of forecasting)

# %%
lags = [1, 3, 6, 12, 24]  # 5-min intervals

for lag in lags:
    df[f"lag_{lag}"] = df["traffic_flow"].shift(lag)

# %% [markdown]
# Rolling statistics (trend & volatility)

# %%
windows = [6, 12, 24]

for window in windows:
    df[f"roll_mean_{window}"] = df["traffic_flow"].rolling(window).mean()
    df[f"roll_std_{window}"] = df["traffic_flow"].rolling(window).std()

# %% [markdown]
# Drop NaNs created by features

# %%
df = df.dropna()
df.head()
# Out:
#                      traffic_flow  hour  day_of_week  is_weekend      lag_1  \
# timestamp
# 2017-01-01 02:00:00     62.813790     2            6           1  67.012016
# 2017-01-01 02:05:00     67.492250     2            6           1  62.813790
# 2017-01-01 02:10:00     61.117262     2            6           1  67.492250
# 2017-01-01 02:15:00     65.200000     2            6           1  61.117262
# 2017-01-01 02:20:00     40.900000     2            6           1  65.200000
#
#                          lag_3      lag_6     lag_12     lag_24  roll_mean_6  \
# timestamp
# 2017-01-01 02:00:00  66.181734  65.359890  65.465191  65.831430    63.824131
# 2017-01-01 02:05:00  62.058451  61.619649  63.235851  65.468198    64.802898
# 2017-01-01 02:10:00  67.012016  63.259146  62.944482  65.468198    64.445917
# 2017-01-01 02:15:00  62.813790  66.181734  63.998413  65.468198    64.282295
# 2017-01-01 02:20:00  67.492250  62.058451  65.381665  65.468198    60.755886
#
#                      roll_std_6  roll_mean_12  roll_std_12  roll_mean_24  \
# timestamp
# 2017-01-01 02:00:00    2.237779     63.960167     1.672746     64.016883
# 2017-01-01 02:05:00    2.361598     64.314866     1.935790     64.101219
# 2017-01-01 02:10:00    2.768460     64.162598     2.116785     63.919930
# 2017-01-01 02:15:00    2.672706     64.262730     2.136640     63.908755
# 2017-01-01 02:20:00   10.028855     62.222592     7.037798     62.885080
#
#                      roll_std_24
# timestamp
# 2017-01-01 02:00:00     1.985902
# 2017-01-01 02:05:00     2.090441
# 2017-01-01 02:10:00     2.154422
# 2017-01-01 02:15:00     2.146724
# 2017-01-01 02:20:00     5.140694

# %% [markdown]
# save feature-engineered dataset

# %%
df.to_csv("../data/processed/traffic_features.csv")
